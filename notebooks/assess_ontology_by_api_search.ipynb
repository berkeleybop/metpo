# %%
import requests
import json
import os
import pandas as pd
import time
from pathlib import Path
from dotenv import load_dotenv
from collections import Counter
import Levenshtein

# %%
metpo_df = pd.read_csv("../data/metpo_terms/metpo_sample_labels.tsv", sep="\t", names=["metpo_id", "metpo_label"])
output_file = "../data/ontology_assessments/phase1_raw_results.tsv"
hq_file = "../data/ontology_assessments/phase1_high_quality_matches.tsv"
summary_stats_json = "../data/ontology_assessments/phase1_summary_stats.json"

# %%
requested_match_count = 75  # Number of results to request per API call
high_quality_similarity_ratio = 0.5

# %%
# Load environment variables
env_path = Path("..") / ".env"
load_dotenv(dotenv_path=env_path)

BIOPORTAL_API_KEY = os.getenv("BIOPORTAL_API_KEY")

if not BIOPORTAL_API_KEY:
    print("⚠️  Warning: BIOPORTAL_API_KEY not set")
else:
    print("✓ BioPortal API key loaded")
# Out:
# ✓ BioPortal API key loaded

# %%
# Define search functions
def search_ols(label, rows=requested_match_count):
    """Search OLS4 for a label"""
    url = "https://www.ebi.ac.uk/ols4/api/search"
    params = {"q": label, "type": "class", "rows": rows}

    try:
        response = requests.get(url, params=params, timeout=10)
        if response.status_code == 200:
            data = response.json()
            docs = data.get("response", {}).get("docs", [])
            return [{"label": d.get("label"),
                     "iri": d.get("iri"),
                     "ontology": d.get("ontology_name"),
                     "definition": d.get("description", [""])[0] if d.get("description") else ""}
                    for d in docs]
        return []
    except Exception as e:
        print(f"OLS error for '{label}': {e}")
        return []

# %%
def search_bioportal(label, api_key, pagesize=requested_match_count):
    """Search BioPortal for a label"""
    url = "https://data.bioontology.org/search"
    params = {"q": label, "pagesize": pagesize}
    headers = {}
    
    if api_key:
        headers["Authorization"] = f"apikey token={api_key}"
    
    try:
        response = requests.get(url, params=params, headers=headers, timeout=10)
        if response.status_code == 200:
            data = response.json()
            collection = data.get("collection", [])
            results = []
            for item in collection:
                ontology_url = item.get("links", {}).get("ontology", "")
                ontology = ontology_url.split("/")[-1] if ontology_url else "unknown"
                
                results.append({
                    "label": item.get("prefLabel"),
                    "iri": item.get("@id"),
                    "ontology": ontology,
                    "definition": item.get("definition", [""])[0] if isinstance(item.get("definition"), list) else item.get("definition", "")
                })
            return results
        return []
    except Exception as e:
        print(f"BioPortal error for '{label}': {e}")
        return []

# %%
# Load METPO sample labels (20% sample = 50 classes)
print(f"\nLoaded {len(metpo_df)} METPO labels (20% sample)")
print(f"Estimated runtime: ~{len(metpo_df) * 2} seconds (~{len(metpo_df) * 2 / 60:.1f} minutes)")
# Out:
# Loaded 50 METPO labels (20% sample)
# Estimated runtime: ~100 seconds (~1.7 minutes)

# %%
metpo_df
# Out:
#          metpo_id                              metpo_label
# 0   METPO:1000678                              oval shaped
# 1   METPO:1000481                          NaCl delta mid2
# 2   METPO:1001002           growth temperature observation
# 3   METPO:1000802                    Anaerobic respiration
# 4   METPO:1000883                   cell length very small
# 5   METPO:1000664                      organoheterotrophic
# 6   METPO:1001023                           pH observation
# 7   METPO:1000476                            pH delta mid2
# 8   METPO:1000614                            psychrophilic
# 9   METPO:1000304                      temperature optimum
# 10  METPO:1000672                          dumbbell shaped
# 11  METPO:1001009                   NaCl range observation
# 12  METPO:1003031                  carotenoid pigmentation
# 13  METPO:1000605                  facultatively anaerobic
# 14  METPO:1000127                               GC content
# 15  METPO:1000696                        triangular shaped
# 16  METPO:1000685                              star shaped
# 17  METPO:1000443                 temperature optimum mid1
# 18  METPO:1000467                        NaCl optimum mid2
# 19  METPO:1000604                          microaerophilic
# 20  METPO:1000673                              ellipsoidal
# 21  METPO:1001104                        biosafety level 3
# 22  METPO:1000652                              mixotrophic
# 23  METPO:1000334                               NaCl range
# 24  METPO:1000624                           non halophilic
# 25  METPO:1000442                  temperature optimum low
# 26  METPO:1000059                                phenotype
# 27  METPO:1000646                         hydrogenotrophic
# 28  METPO:1000611                       strictly anaerobic
# 29  METPO:1000649                             lithotrophic
# 30  METPO:1001017                growth oxygen observation
# 31  METPO:1000232                                 pH delta
# 32  METPO:1000486                   temperature delta mid2
# 33  METPO:1000648                       lithoheterotrophic
# 34  METPO:1000701                                 motility
# 35  METPO:1000472                          NaCl range high
# 36  METPO:1000621                         haloalkaliphilic
# 37  METPO:1000706                                  gliding
# 38  METPO:1000473                        pH delta very low
# 39  METPO:1000536  optimum phenotype with numerical limits
# 40  METPO:1000658                        photolithotrophic
# 41  METPO:1000612            facultative oxygen preference
# 42  METPO:1000468                        NaCl optimum high
# 43  METPO:1000634                    chemoautolithotrophic
# 44  METPO:1003029                          white pigmented
# 45  METPO:1000650                           methanotrophic
# 46  METPO:1000803                Oxidative phosphorylation
# 47  METPO:1000695                            tailed shaped
# 48  METPO:1000615                               mesophilic
# 49  METPO:1000480                          NaCl delta mid1

# %%
# Run batch search
all_results = []

# %%
for idx, row in metpo_df.iterrows():
    metpo_id = row["metpo_id"]
    metpo_label = row["metpo_label"]
    
    print(f"\n[{idx+1}/{len(metpo_df)}] Searching: {metpo_label}")
    
    # Search OLS
    ols_results = search_ols(metpo_label)
    print(f"  OLS: {len(ols_results)} results")
    
    for result in ols_results:
        all_results.append({
            "metpo_id": metpo_id,
            "metpo_label": metpo_label,
            "source": "OLS",
            "match_label": result["label"],
            "match_iri": result["iri"],
            "match_ontology": result["ontology"],
            "match_definition": result["definition"]
        })
    
    # Search BioPortal
    bp_results = search_bioportal(metpo_label, BIOPORTAL_API_KEY)
    print(f"  BioPortal: {len(bp_results)} results")
    
    for result in bp_results:
        all_results.append({
            "metpo_id": metpo_id,
            "metpo_label": metpo_label,
            "source": "BioPortal",
            "match_label": result["label"],
            "match_iri": result["iri"],
            "match_ontology": result["ontology"],
            "match_definition": result["definition"]
        })
    
    # Rate limiting
    time.sleep(0.5)

print(f"\n✓ Complete: {len(all_results)} total results")
# Out:
# [1/50] Searching: oval shaped
#   OLS: 75 results
#   BioPortal: 75 results
#
# [2/50] Searching: NaCl delta mid2
#   OLS: 75 results
#   BioPortal: 75 results
#
# [3/50] Searching: growth temperature observation
#   OLS: 75 results
#   BioPortal: 75 results
#
# [4/50] Searching: Anaerobic respiration
#   OLS: 75 results
#   BioPortal: 75 results
#
# [5/50] Searching: cell length very small
#   OLS: 75 results
#   BioPortal: 75 results
#
# [6/50] Searching: organoheterotrophic
#   OLS: 0 results
#   BioPortal: 2 results
#
# [7/50] Searching: pH observation
#   OLS: 75 results
#   BioPortal: 75 results
#
# [8/50] Searching: pH delta mid2
#   OLS: 75 results
#   BioPortal: 75 results
#
# [9/50] Searching: psychrophilic
#   OLS: 30 results
#   BioPortal: 13 results
#
# [10/50] Searching: temperature optimum
#   OLS: 75 results
#   BioPortal: 75 results
#
# [11/50] Searching: dumbbell shaped
#   OLS: 75 results
#   BioPortal: 75 results
#
# [12/50] Searching: NaCl range observation
#   OLS: 75 results
#   BioPortal: 75 results
#
# [13/50] Searching: carotenoid pigmentation
#   OLS: 75 results
#   BioPortal: 75 results
#
# [14/50] Searching: facultatively anaerobic
#   OLS: 75 results
#   BioPortal: 75 results
#
# [15/50] Searching: GC content
#   OLS: 75 results
#   BioPortal: 75 results
#
# [16/50] Searching: triangular shaped
#   OLS: 75 results
#   BioPortal: 75 results
#
# [17/50] Searching: star shaped
#   OLS: 75 results
#   BioPortal: 75 results
#
# [18/50] Searching: temperature optimum mid1
#   OLS: 75 results
#   BioPortal: 75 results
#
# [19/50] Searching: NaCl optimum mid2
#   OLS: 75 results
#   BioPortal: 75 results
#
# [20/50] Searching: microaerophilic
#   OLS: 75 results
#   BioPortal: 27 results
#
# [21/50] Searching: ellipsoidal
#   OLS: 31 results
#   BioPortal: 9 results
#
# [22/50] Searching: biosafety level 3
#   OLS: 75 results
#   BioPortal: 75 results
#
# [23/50] Searching: mixotrophic
#   OLS: 8 results
#   BioPortal: 5 results
#
# [24/50] Searching: NaCl range
#   OLS: 75 results
#   BioPortal: 75 results
#
# [25/50] Searching: non halophilic
#   OLS: 75 results
#   BioPortal: 75 results
#
# [26/50] Searching: temperature optimum low
#   OLS: 75 results
#   BioPortal: 75 results
#
# [27/50] Searching: phenotype
#   OLS: 75 results
#   BioPortal: 75 results
#
# [28/50] Searching: hydrogenotrophic
#   OLS: 0 results
#   BioPortal: 5 results
#
# [29/50] Searching: strictly anaerobic
#   OLS: 75 results
#   BioPortal: 75 results
#
# [30/50] Searching: lithotrophic
#   OLS: 3 results
#   BioPortal: 5 results
#
# [31/50] Searching: growth oxygen observation
#   OLS: 75 results
#   BioPortal: 75 results
#
# [32/50] Searching: pH delta
#   OLS: 75 results
#   BioPortal: 75 results
#
# [33/50] Searching: temperature delta mid2
#   OLS: 75 results
#   BioPortal: 75 results
#
# [34/50] Searching: lithoheterotrophic
#   OLS: 0 results
#   BioPortal: 2 results
#
# [35/50] Searching: motility
#   OLS: 75 results
#   BioPortal: 75 results
#
# [36/50] Searching: NaCl range high
#   OLS: 75 results
#   BioPortal: 75 results
#
# [37/50] Searching: haloalkaliphilic
#   OLS: 25 results
#   BioPortal: 1 results
#
# [38/50] Searching: gliding
#   OLS: 75 results
#   BioPortal: 75 results
#
# [39/50] Searching: pH delta very low
#   OLS: 75 results
#   BioPortal: 75 results
#
# [40/50] Searching: optimum phenotype with numerical limits
#   OLS: 75 results
#   BioPortal: 75 results
#
# [41/50] Searching: photolithotrophic
#   OLS: 3 results
#   BioPortal: 2 results
#
# [42/50] Searching: facultative oxygen preference
#   OLS: 75 results
#   BioPortal: 75 results
#
# [43/50] Searching: NaCl optimum high
#   OLS: 75 results
#   BioPortal: 75 results
#
# [44/50] Searching: chemoautolithotrophic
#   OLS: 0 results
#   BioPortal: 1 results
#
# [45/50] Searching: white pigmented
#   OLS: 75 results
#   BioPortal: 75 results
#
# [46/50] Searching: methanotrophic
#   OLS: 75 results
#   BioPortal: 3 results
#
# [47/50] Searching: Oxidative phosphorylation
#   OLS: 75 results
#   BioPortal: 75 results
#
# [48/50] Searching: tailed shaped
#   OLS: 75 results
#   BioPortal: 75 results
#
# [49/50] Searching: mesophilic
#   OLS: 44 results
#   BioPortal: 17 results
#
# [50/50] Searching: NaCl delta mid1
#   OLS: 75 results
#   BioPortal: 75 results
#
# ✓ Complete: 5936 total results

# %%
# Convert to DataFrame and calculate string distances
results_df = pd.DataFrame(all_results)

# %%
results_df = results_df[~results_df["match_iri"].str.contains("metpo", case=False, na=False)]
print(f"After removing self-matches: {len(results_df)} results")
# Out:
# After removing self-matches: 5527 results

# %%
# Calculate Levenshtein distance and normalized similarity
results_df["levenshtein_distance"] = results_df.apply(
    lambda row: Levenshtein.distance(
        str(row["metpo_label"]).lower(),
        str(row["match_label"]).lower()
    ) if pd.notna(row["match_label"]) else None,
    axis=1
)

# %%
# Normalized similarity ratio (0-1, where 1 is exact match)
results_df["similarity_ratio"] = results_df.apply(
    lambda row: Levenshtein.ratio(
        str(row["metpo_label"]).lower(),
        str(row["match_label"]).lower()
    ) if pd.notna(row["match_label"]) else None,
    axis=1
)

# %%
print(f"Results shape: {results_df.shape}")
print(f"\nSimilarity statistics:")
# Out:
# Results shape: (5527, 9)
#
# Similarity statistics:

# %%
results_df["similarity_ratio"].describe()
# Out:
# count    5527.000000
# mean        0.527694
# std         0.195134
# min         0.000000
# 25%         0.391304
# 50%         0.512821
# 75%         0.652174
# max         1.000000
# Name: similarity_ratio, dtype: float64

# %%
results_df
# Out:
#            metpo_id      metpo_label     source  \
# 0     METPO:1000678      oval shaped        OLS
# 1     METPO:1000678      oval shaped        OLS
# 2     METPO:1000678      oval shaped        OLS
# 3     METPO:1000678      oval shaped        OLS
# 4     METPO:1000678      oval shaped        OLS
# ...             ...              ...        ...
# 5928  METPO:1000480  NaCl delta mid1  BioPortal
# 5929  METPO:1000480  NaCl delta mid1  BioPortal
# 5930  METPO:1000480  NaCl delta mid1  BioPortal
# 5931  METPO:1000480  NaCl delta mid1  BioPortal
# 5932  METPO:1000480  NaCl delta mid1  BioPortal
#
#                                   match_label  \
# 0                          Oval shaped lesion
# 1                                        Oval
# 2                              Oval macrocyte
# 3                                oval nucleus
# 4                                oval nucleus
# ...                                       ...
# 5928                   MID1, 3-BP DEL, MET438
# 5929       Mid1-interacting protein 1 (human)
# 5930         Mid1-interacting protein 1 (rat)
# 5931       Mid1-interacting protein 1 (mouse)
# 5932  Mid1-interacting protein 1A (zebrafish)
#
#                                               match_iri match_ontology  \
# 0                       http://snomed.info/id/129734009         snomed
# 1            http://purl.obolibrary.org/obo/NCIT_C48345           ncit
# 2                       http://snomed.info/id/117170009         snomed
# 3            http://purl.obolibrary.org/obo/EMAPA_37667          emapa
# 4             http://purl.obolibrary.org/obo/MA_0000929             ma
# ...                                                 ...            ...
# 5928  http://purl.bioontology.org/ontology/OMIM/3005...           OMIM
# 5929           http://purl.obolibrary.org/obo/PR_Q9NPA3             PR
# 5930           http://purl.obolibrary.org/obo/PR_Q6P7D5             PR
# 5931           http://purl.obolibrary.org/obo/PR_Q9CQ20             PR
# 5932           http://purl.obolibrary.org/obo/PR_P47805             PR
#
#                                        match_definition  levenshtein_distance  \
# 0                                                                           7
# 1     The shape of either an oval or an ellipse.  Se...                     7
# 2                                                                           9
# 3                                                                           6
# 4                                                                           6
# ...                                                 ...                   ...
# 5928                                                                       17
# 5929  A Mid1-interacting protein 1 that is encoded i...                    27
# 5930  A Mid1-interacting protein 1 that is encoded i...                    26
# 5931  A Mid1-interacting protein 1 that is encoded i...                    27
# 5932  A protein that is a translation product of the...                    31
#
#       similarity_ratio
# 0             0.758621
# 1             0.533333
# 2             0.560000
# 3             0.521739
# 4             0.521739
# ...                ...
# 5928          0.324324
# 5929          0.285714
# 5930          0.297872
# 5931          0.285714
# 5932          0.296296
#
# [5527 rows x 9 columns]

# %%
# Save raw results with all columns
results_df.to_csv(output_file, sep="\t", index=False)
print(f"✓ Saved full results to {output_file}")
# Out:
# ✓ Saved full results to ../data/ontology_assessments/phase1_raw_results.tsv

# %%
# Also save high-quality matches separately
high_quality = results_df[results_df["similarity_ratio"] >= 0.5]

# %%
high_quality.to_csv(hq_file, sep="\t", index=False)
print(f"✓ Saved high-quality matches (similarity ≥ 0.5) to {hq_file}")
# Out:
# ✓ Saved high-quality matches (similarity ≥ 0.5) to ../data/ontology_assessments/phase1_high_quality_matches.tsv

# %%
# Save summary statistics
summary_stats = {
    "total_metpo_terms": len(metpo_df),
    "total_results": len(results_df),
    "high_quality_results": len(high_quality),
    "unique_ontologies": results_df["match_ontology"].nunique(),
    "avg_similarity": results_df["similarity_ratio"].mean(),
    "median_similarity": results_df["similarity_ratio"].median()
}

# %%
with open(summary_stats_json, "w") as f:
    json.dump(summary_stats, f, indent=2)
print(f"✓ Saved summary statistics to phase1_summary_stats.json")
# Out:
# ✓ Saved summary statistics to phase1_summary_stats.json

# %% [markdown]
# ## Analysis: Ontology Frequency

# %%
# Count ontologies
ontology_counts = results_df["match_ontology"].value_counts()
print("Top 20 ontologies by result count:\n")
# Out:
# Top 20 ontologies by result count:

# %%
ontology_counts
# Out:
# match_ontology
# ncbitaxon    481
# snomed       462
# ncit         346
# SNOMEDCT     160
# pato         132
#             ...
# MFOMD          1
# FGNHNS         1
# VEO            1
# JFO            1
# VBO            1
# Name: count, Length: 472, dtype: int64

# %%
# Break down by source
print("\n=== OLS Ontologies ===")
ols_df = results_df[results_df["source"] == "OLS"]
# Out:
# === OLS Ontologies ===

# %%
ols_df["match_ontology"].value_counts()
# Out:
# match_ontology
# ncbitaxon    481
# snomed       462
# ncit         346
# pato         132
# mesh         131
#             ...
# slso           1
# probonto       1
# eupath         1
# mf             1
# vbo            1
# Name: count, Length: 145, dtype: int64

# %%
print("\n=== BioPortal Ontologies ===")
bp_df = results_df[results_df["source"] == "BioPortal"]
# Out:
# === BioPortal Ontologies ===

# %%
bp_df["match_ontology"].value_counts()
# Out:
# match_ontology
# SNOMEDCT    160
# OCHV        118
# RCD          87
# IOBC         82
# RH-MESH      76
#            ...
# MF            1
# FGNHNS        1
# MIRO          1
# JFO           1
# VBO           1
# Name: count, Length: 327, dtype: int64

# %% [markdown]
# ## Analysis: Label Similarity

# %%
# Analyze ontology distribution by similarity quality
print(f"\n=== Phase 2 Filter Recommendations ===")

# Filter to high-quality matches (similarity > 0.5)
high_quality = results_df[results_df["similarity_ratio"] >= high_quality_similarity_ratio]
print(f"\nHigh-quality matches (similarity ≥ 0.5): {len(high_quality)} / {len(results_df)} ({len(high_quality)/len(results_df)*100:.1f}%)")
# Out:
# === Phase 2 Filter Recommendations ===
#
# High-quality matches (similarity ≥ 0.5): 3036 / 5527 (54.9%)

# %%
# Top ontologies by high-quality match count
print(f"\nTop ontologies by HIGH-QUALITY match count:")
hq_ontology_counts = high_quality["match_ontology"].value_counts()
# Out:
# Top ontologies by HIGH-QUALITY match count:

# %%
hq_ontology_counts
# Out:
# match_ontology
# snomed       255
# ncit         156
# ncbitaxon    122
# pato         114
# flopo        105
#             ...
# HAAURAADO      1
# emapa          1
# JFO            1
# VBO            1
# NMR            1
# Name: count, Length: 392, dtype: int64

# %%
# Compare to all matches
print(f"\nTop ontologies by TOTAL match count (including low similarity):")
# Out:
# Top ontologies by TOTAL match count (including low similarity):

# %%
ontology_counts
# Out:
# match_ontology
# ncbitaxon    481
# snomed       462
# ncit         346
# SNOMEDCT     160
# pato         132
#             ...
# MFOMD          1
# FGNHNS         1
# VEO            1
# JFO            1
# VBO            1
# Name: count, Length: 472, dtype: int64

# %%
# Show cumulative coverage for high-quality matches
cumulative_pct = (hq_ontology_counts.cumsum() / hq_ontology_counts.sum() * 100)
print(f"\nCumulative coverage of high-quality matches:")
if len(cumulative_pct) >= 5:
    print(f"  Top 5 ontologies: {cumulative_pct.iloc[4]:.1f}%")
if len(cumulative_pct) >= 10:
    print(f"  Top 10 ontologies: {cumulative_pct.iloc[9]:.1f}%")
if len(cumulative_pct) >= 20:
    print(f"  Top 20 ontologies: {cumulative_pct.iloc[19]:.1f}%")
# Out:
# Cumulative coverage of high-quality matches:
#   Top 5 ontologies: 24.8%
#   Top 10 ontologies: 37.0%
#   Top 20 ontologies: 51.2%

# %%
# Show average similarity by ontology
print(f"\nAverage similarity ratio by ontology (top 20):")
ontology_avg_sim = results_df.groupby("match_ontology")["similarity_ratio"].agg(["mean", "count"]).sort_values("mean", ascending=False)
# Out:
# Average similarity ratio by ontology (top 20):

# %%
ontology_avg_sim
# Out:
#                     mean  count
# match_ontology
# wikipathways    1.000000      5
# sbo             1.000000      1
# ro              1.000000      1
# pso             1.000000      1
# COVID-19        1.000000      1
# ...                  ...    ...
# ONTOTOXNUC      0.266667      1
# chiro           0.260870      2
# ICD10CM         0.258718     12
# poro            0.220238      2
# vto             0.194125      3
#
# [472 rows x 2 columns]

# %% [markdown]
# ## Analysis: Coverage by METPO Term

# %%
# How many results per METPO term?
coverage = results_df.groupby("metpo_label").agg({
    "match_label": "count",
    "match_ontology": lambda x: x.nunique()
}).rename(columns={"match_label": "total_results", "match_ontology": "unique_ontologies"})

coverage = coverage.sort_values("total_results", ascending=False)
print("Results per METPO term:\n")
# Out:
# Results per METPO term:

# %%
coverage
# Out:
#                                          total_results  unique_ontologies
# metpo_label
# phenotype                                          150                115
# carotenoid pigmentation                            149                 62
# dumbbell shaped                                    149                 40
# Oxidative phosphorylation                          149                 69
# tailed shaped                                      149                 35
# motility                                           149                 42
# oval shaped                                        149                 55
# gliding                                            149                 43
# Anaerobic respiration                              149                 60
# triangular shaped                                  149                 26
# star shaped                                        149                 22
# white pigmented                                    149                 58
# strictly anaerobic                                 148                 56
# facultative oxygen preference                      147                 58
# GC content                                         145                 57
# pH observation                                     145                 74
# facultatively anaerobic                            145                 48
# non halophilic                                     145                 35
# biosafety level 3                                  144                 41
# cell length very small                             144                 54
# pH delta                                           142                 80
# growth temperature observation                     142                 50
# growth oxygen observation                          141                 70
# pH delta very low                                  138                 45
# NaCl range observation                             135                 68
# temperature delta mid2                             134                 60
# pH delta mid2                                      133                 65
# NaCl range                                         130                 56
# NaCl delta mid1                                    129                 38
# NaCl range high                                    128                 56
# temperature optimum                                128                 54
# temperature optimum low                            124                 48
# NaCl delta mid2                                    123                 51
# optimum phenotype with numerical limits            123                 40
# temperature optimum mid1                           122                 46
# NaCl optimum mid2                                  118                 43
# NaCl optimum high                                  113                 39
# microaerophilic                                    101                 38
# methanotrophic                                      77                  7
# mesophilic                                          60                 17
# psychrophilic                                       41                  9
# ellipsoidal                                         39                 22
# haloalkaliphilic                                    25                  2
# mixotrophic                                         12                  7
# lithotrophic                                         7                  6
# hydrogenotrophic                                     4                  2
# photolithotrophic                                    4                  2
# organoheterotrophic                                  1                  1
# lithoheterotrophic                                   1                  1

# %% [markdown]
# ## Recommendations for Phase 2 Filters

# %%
# Recommended ontology whitelist (top ontologies of interest)
target_ontologies = ["omp", "pato", "mco", "envo", "chebi", "go", "ncbitaxon"]
target_results = results_df[results_df["match_ontology"].str.lower().isin(target_ontologies)]

# %%
print(f"\n=== Phase 2 Recommendations ===")
print(f"\nTarget ontologies: {', '.join(target_ontologies)}")
print(f"Results from target ontologies: {len(target_results)} / {len(results_df)} ({len(target_results)/len(results_df)*100:.1f}%)")
print(f"\nTarget ontology breakdown:")
# Out:
# === Phase 2 Recommendations ===
#
# Target ontologies: omp, pato, mco, envo, chebi, go, ncbitaxon
# Results from target ontologies: 905 / 5527 (16.4%)
#
# Target ontology breakdown:

# %%
target_results["match_ontology"].value_counts()
# Out:
# match_ontology
# ncbitaxon    481
# pato         132
# go            64
# omp           61
# OMP           47
# mco           31
# envo          24
# chebi         18
# PATO          13
# GO             9
# CHEBI          8
# ENVO           8
# NCBITAXON      7
# MCO            2
# Name: count, dtype: int64

# %%
exact_matches = results_df[results_df["similarity_ratio"] == 1.0]

# %%
# Summary statistics
print("\n=== Summary Statistics ===")
print(f"Total METPO terms searched: {metpo_df.shape[0]}")
print(f"Total results found: {len(results_df)}")
print(f"Average results per term: {len(results_df) / metpo_df.shape[0]:.1f}")
print(f"Unique ontologies found: {results_df['match_ontology'].nunique()}")
print(f"Terms with exact matches: {exact_matches['metpo_label'].nunique()}")
print(f"Terms with NO results: {metpo_df.shape[0] - coverage.shape[0]}")
# Out:
# === Summary Statistics ===
# Total METPO terms searched: 50
# Total results found: 5527
# Average results per term: 110.5
# Unique ontologies found: 472
# Terms with exact matches: 19
# Terms with NO results: 1

# %%
exact_matches
# Out:
#            metpo_id                metpo_label     source  \
# 450   METPO:1000802      Anaerobic respiration        OLS
# 451   METPO:1000802      Anaerobic respiration        OLS
# 452   METPO:1000802      Anaerobic respiration        OLS
# 453   METPO:1000802      Anaerobic respiration        OLS
# 454   METPO:1000802      Anaerobic respiration        OLS
# ...             ...                        ...        ...
# 5537  METPO:1000803  Oxidative phosphorylation  BioPortal
# 5538  METPO:1000803  Oxidative phosphorylation  BioPortal
# 5539  METPO:1000803  Oxidative phosphorylation  BioPortal
# 5725  METPO:1000615                 mesophilic        OLS
# 5769  METPO:1000615                 mesophilic  BioPortal
#
#                     match_label                                     match_iri  \
# 450       anaerobic respiration     http://purl.obolibrary.org/obo/GO_0009061
# 451       anaerobic respiration     http://purl.obolibrary.org/obo/GO_0009061
# 452       anaerobic respiration     http://purl.obolibrary.org/obo/GO_0009061
# 453       anaerobic respiration     http://purl.obolibrary.org/obo/GO_0009061
# 454       anaerobic respiration     http://purl.obolibrary.org/obo/GO_0009061
# ...                         ...                                           ...
# 5537  oxidative phosphorylation     http://purl.obolibrary.org/obo/GO_0006119
# 5538  oxidative phosphorylation     http://purl.obolibrary.org/obo/GO_0006119
# 5539  Oxidative phosphorylation    http://purl.obolibrary.org/obo/IEV_0001431
# 5725                 mesophilic  http://purl.obolibrary.org/obo/MICRO_0000111
# 5769                 Mesophilic           http://purl.jp/bio/10/mpo#MPO_03022
#
#      match_ontology                                   match_definition  \
# 450              go  The enzymatic release of energy from inorganic...
# 451             gaz
# 452            envo
# 453         ecocore  The enzymatic release of energy from inorganic...
# 454             oba
# ...             ...                                                ...
# 5537          PHAGE  The phosphorylation of ADP to ATP that accompa...
# 5538       COVID-19  The phosphorylation of ADP to ATP that accompa...
# 5539            PTS  "The phosphorylation of ADP to ATP that accomp...
# 5725          micro
# 5769            MPO  A mibrobial organism that thrives at moderate ...
#
#       levenshtein_distance  similarity_ratio
# 450                      0               1.0
# 451                      0               1.0
# 452                      0               1.0
# 453                      0               1.0
# 454                      0               1.0
# ...                    ...               ...
# 5537                     0               1.0
# 5538                     0               1.0
# 5539                     0               1.0
# 5725                     0               1.0
# 5769                     0               1.0
#
# [272 rows x 9 columns]
